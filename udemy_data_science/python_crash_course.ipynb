# %% [markdown]
# # Python Crash Course:

# %% [markdown]
# ## Data Types:

# %%
# this is an integer
1
# Out:
# 1

# %%
# this is a float
1.0
# Out:
# 1.0

# %%
# this allows us to check the type of the variable
type(1)
# Out:
# int

# %%
# this allows us to check the type of the variable
type(1.0)
# Out:
# float

# %%
# this allows us to check the type of the variable
lst = [1,2,3]
type(lst)
# Out:
# list

# %%
# addition operator
1 + 1
# Out:
# 2

# %%
# division operator
3/5
# Out:
# 0.6

# %%
# exponential operator
2**9
# Out:
# 512

# %%
# modulus operator returning the remainder
4 % 2
# Out:
# 0

# %%
[1,2,3]
# creating a list
# Out:
# [1, 2, 3]

# %%
# creating a list with strings and integers
[1, 'a', 2, 'b', 3, 'c']
# Out:
# [1, 'a', 2, 'b', 3, 'c']

# %%
mylist = ['a','b','c'] 

# creating a list and accessing the first element
mylist[0]
# Out:
# 'a'

# %%
# accessing the second and last element
mylist[1:]
# Out:
# ['b', 'c']

# %%
# accessing the last element
mylist[-1]
# Out:
# 'c'

# %%
# accessing the first element
mylist[-3]
# Out:
# 'a'

# %%
# appending an element to the list
mylist.append('d')

# %%
# removing the last element from the list
mylist.pop()
# Out:
# 'd'

# %%
# removing the first element from the list
mylist.pop(0)
# Out:
# 'a'

# %%
# reversing the list
mylist.reverse()

# %%
# index of the element 'b'
mylist.index('b')
# Out:
# 1

# %%
# sorting the list
mylist.sort()

# %%
newlist = [1,2, [100,300]]

# creating a nested list and accessing the second element
newlist[2][1]
# Out:
# 300

# %%
# dictionaries also know as hash tables in other languages 

d = {'key1':123, 'key2':[12,23,33], 'key3':['item0','item1','item2']} 
d['key1']
# Out:
# 123

# %%
0 == False
1 == True
# Out:
# True

# %%
t = (1,2,3)
# this is a tuple
type(t)
# this is a tuple
t[0]
# this is a tuple
t[0]
# Out:
# 1

# %%
# use case for tuples is when we want to store data that should not be changed 
# like days of the week, months of the year, etc. 
# tuples are faster than lists 
# tuples are more memory efficient than lists 
# tuples are more secure than lists 
# tuples are more readable than lists 
# tuples are more readable than lists

# %% [markdown]
# ## Python Crash Course Exercises & Solutions:

# %% [markdown]
# #### What is 7 to the power 4?

# %%
print(7**4)
# Out:
# 2401

# %% [markdown]
# #### For the mentioned string in S, split it using which function?

# %%
s = "Hi there Sam!"
s.split()
# Out:
# ['Hi', 'there', 'Sam!']

# %% [markdown]
# #### Using the .format() function print the below statement

# %%
planet = "Earth"
diameter = 12742

print("The diameter of {planet} is {diameter} kilometers.".format(planet=planet, diameter=diameter))
# Out:
# The diameter of Earth is 12742 kilometers.

# %% [markdown]
# #### From the below list, pick 'hello':

# %%
lst = [1,2,[3,4], [5,[100,200,['hello']],23,11],1,7]

# %%
lst[3][1][2]
# Out:
# ['hello']

# %% [markdown]
# #### From the below dictionary, pick 'hello':

# %%
d = {'k1': [1,2,3, {'tricky': ['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
d['k1'][3]['tricky'][3]['target'][3]
# Out:
# 'hello'

# %% [markdown]
# #### Create an If-Else Statement for Ticket Speeding:

# %%
def caught_speeding(speed, is_birthday):
    if is_birthday:
        speed -= 5
    if speed <= 60:
        return 'No ticket'
    elif speed > 60 and speed <= 80:
        return 'Small ticket'
    else:
        return 'Big ticket'

# %%
caught_speeding(81, False)
# Out:
# 'Big ticket'
